# %%
import requests
from bs4 import BeautifulSoup as soup

# %%
# You may encounter an issue here. I can get successful StatusCode 200 in my country
# but with some foreigh destinations, I need to rerun this step for a couple of times. I'll try to fix it.
html = requests.get('https://www.tripadvisor.com.tr/Hotels-g14984534-Marmaris_District_Mugla_Province_Turkish_Aegean_Coast-Hotels.html')
html.status_code
# Out:
# 200

# %%
bsobj = soup(html.content,'lxml')

# %%
hotel = []
for name in bsobj.findAll('div',{'class':'listing_title'}):
    hotel.append(name.text.strip())
     
hotel
# Out:
# ['Sponsorlu      Dionysos Village Hotel',
#  'TUI BLUE Grand Azur',
#  'Green Nature Diamond Hotel',
#  'Blue Bay Platinum Hotel',
#  'Sea Star Marmaris',
#  'Green Nature Resort & Spa',
#  'Sponsorlu      Sabrinas Haus',
#  'The Beachfront Hotel',
#  'Motto Premium Hotel',
#  'Club Adakoy',
#  'Otel Aqua',
#  'Labranda Mares Marmaris',
#  'Grand Yazıcı Club Marmaris Palace',
#  'Paşa Beach Otel',
#  'Grand Aquarium',
#  'Elegance Hotels International Marmaris',
#  'Sunset Hotel Marmaris',
#  'Greenpark Apartments',
#  'Angels Inn',
#  'Romance Hotel Marmaris',
#  'Moda Beach Hotel',
#  'Two Seas Hotel',
#  'Club Sema Suite Hotel',
#  'City Hotel Marmaris',
#  'Chicago hotel',
#  'Club Sultan Maris',
#  'B&B Yüzbaşı Beach',
#  'Kemal Butik Hotel',
#  'Ünver Hotel',
#  'Cettia Beach Resort Hotel',
#  'Sabrinas Haus',
#  'Ideal Prime Beach']

# %%
ratings = []
for rating in bsobj.findAll('a',{'class':'ui_bubble_rating'}):
    ratings.append(rating['alt'])
    
ratings
# Out:
# ['5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa05',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa03,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa03,5',
#  '5 baloncuk üzerinden\xa03',
#  '5 baloncuk üzerinden\xa02,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04']

# %%
reviews = []

for review in bsobj.findAll('a',{'class':'review_count'}):
    reviews.append(review.text.strip())

reviews
# Out:
# ['239 yorum',
#  '698 yorum',
#  '4.068 yorum',
#  '4.382 yorum',
#  '1.493 yorum',
#  '5.486 yorum',
#  '214 yorum',
#  '552 yorum',
#  '242 yorum',
#  '866 yorum',
#  '3.249 yorum',
#  '3.534 yorum',
#  '2.385 yorum',
#  '2.078 yorum',
#  '1.051 yorum',
#  '1.172 yorum',
#  '19 yorum',
#  '698 yorum',
#  '182 yorum',
#  '417 yorum',
#  '380 yorum',
#  '137 yorum',
#  '42 yorum',
#  '130 yorum',
#  '39 yorum',
#  '304 yorum',
#  '146 yorum',
#  '28 yorum',
#  '150 yorum',
#  '1.702 yorum',
#  '214 yorum',
#  '4.047 yorum']

# %%
price = []

for p in bsobj.findAll('div',{'class':'price-wrap'}):
    price.append(p.text.replace('TL','').strip())
    
price[:5]
# Out:
# ['₺3.702', '₺2.261', '₺1.565', '₺1.056', '₺729']

# %%
len(price)
# Out:
# 32

# %%
d1 = {'Hotel':hotel,'Ratings':ratings,'No_of_Reviews':reviews,'Price':price}

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(d1)
df
# Out:
#                                      Hotel                   Ratings  \
# 0    Sponsorlu      Dionysos Village Hotel  5 baloncuk üzerinden 4,5
# 1                      TUI BLUE Grand Azur  5 baloncuk üzerinden 4,5
# 2               Green Nature Diamond Hotel  5 baloncuk üzerinden 4,5
# 3                  Blue Bay Platinum Hotel  5 baloncuk üzerinden 4,5
# 4                        Sea Star Marmaris  5 baloncuk üzerinden 4,5
# 5                Green Nature Resort & Spa    5 baloncuk üzerinden 4
# 6             Sponsorlu      Sabrinas Haus  5 baloncuk üzerinden 4,5
# 7                     The Beachfront Hotel  5 baloncuk üzerinden 4,5
# 8                      Motto Premium Hotel  5 baloncuk üzerinden 4,5
# 9                              Club Adakoy  5 baloncuk üzerinden 4,5
# 10                               Otel Aqua    5 baloncuk üzerinden 5
# 11                 Labranda Mares Marmaris    5 baloncuk üzerinden 4
# 12       Grand Yazıcı Club Marmaris Palace    5 baloncuk üzerinden 4
# 13                         Paşa Beach Otel  5 baloncuk üzerinden 4,5
# 14                          Grand Aquarium  5 baloncuk üzerinden 4,5
# 15  Elegance Hotels International Marmaris    5 baloncuk üzerinden 4
# 16                   Sunset Hotel Marmaris  5 baloncuk üzerinden 4,5
# 17                    Greenpark Apartments  5 baloncuk üzerinden 4,5
# 18                              Angels Inn    5 baloncuk üzerinden 4
# 19                  Romance Hotel Marmaris    5 baloncuk üzerinden 4
# 20                        Moda Beach Hotel  5 baloncuk üzerinden 3,5
# 21                          Two Seas Hotel  5 baloncuk üzerinden 4,5
# 22                   Club Sema Suite Hotel    5 baloncuk üzerinden 4
# 23                     City Hotel Marmaris  5 baloncuk üzerinden 4,5
# 24                           Chicago hotel    5 baloncuk üzerinden 4
# 25                       Club Sultan Maris    5 baloncuk üzerinden 4
# 26                       B&B Yüzbaşı Beach  5 baloncuk üzerinden 3,5
# 27                       Kemal Butik Hotel    5 baloncuk üzerinden 3
# 28                             Ünver Hotel  5 baloncuk üzerinden 2,5
# 29               Cettia Beach Resort Hotel  5 baloncuk üzerinden 4,5
# 30                           Sabrinas Haus  5 baloncuk üzerinden 4,5
# 31                       Ideal Prime Beach    5 baloncuk üzerinden 4
#
#    No_of_Reviews     Price
# 0      239 yorum    ₺3.702
# 1      698 yorum    ₺2.261
# 2    4.068 yorum    ₺1.565
# 3    4.382 yorum    ₺1.056
# 4    1.493 yorum      ₺729
# 5    5.486 yorum      ₺839
# 6      214 yorum    ₺4.885
# 7      552 yorum      ₺603
# 8      242 yorum      ₺343
# 9      866 yorum    ₺1.060
# 10   3.249 yorum    ₺1.330
# 11   3.534 yorum      ₺773
# 12   2.385 yorum      ₺748
# 13   2.078 yorum      ₺728
# 14   1.051 yorum  ₺295₺279
# 15   1.172 yorum    ₺1.112
# 16      19 yorum      ₺766
# 17     698 yorum      ₺238
# 18     182 yorum      ₺146
# 19     417 yorum      ₺603
# 20     380 yorum  ₺427₺218
# 21     137 yorum      ₺250
# 22      42 yorum      ₺260
# 23     130 yorum      ₺312
# 24      39 yorum      ₺208
# 25     304 yorum      ₺210
# 26     146 yorum      ₺260
# 27      28 yorum  ₺223₺129
# 28     150 yorum      ₺156
# 29   1.702 yorum
# 30     214 yorum    ₺4.885
# 31   4.047 yorum
