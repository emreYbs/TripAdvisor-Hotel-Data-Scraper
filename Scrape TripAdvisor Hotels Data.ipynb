# %%
import requests
from bs4 import BeautifulSoup as soup

# %%
html = requests.get('https://www.tripadvisor.com.tr/Hotels-g14984534-Marmaris_District_Mugla_Province_Turkish_Aegean_Coast-Hotels.html')
html.status_code
# Out:
# 200

# %%
bsobj = soup(html.content,'lxml')

# %%
hotel = []
for name in bsobj.findAll('div',{'class':'listing_title'}):
    hotel.append(name.text.strip())
     
hotel
# Out:
# ['Otel Aqua',
#  'Grand Aquarium',
#  'Golden Rock Beach Hotel',
#  'Pilos Deluxe',
#  'Kemal Butik Hotel',
#  'TUI BLUE Grand Azur',
#  'Green Nature Diamond Hotel',
#  'Blue Bay Platinum Hotel',
#  'Green Nature Resort & Spa',
#  'Motto Premium Hotel',
#  'The Beachfront Hotel',
#  'Club Adakoy',
#  'Labranda Mares Marmaris',
#  'Grand Yazıcı Club Marmaris Palace',
#  'Paşa Beach Otel',
#  'Cettia Beach Resort Hotel',
#  'Sabrinas Haus',
#  'Greenpark Apartments',
#  'Elegance Hotels International Marmaris',
#  'Sunset Hotel Marmaris',
#  'Angels Inn',
#  'Romance Hotel Marmaris',
#  'Two Seas Hotel',
#  'Moda Beach Hotel',
#  'City Hotel Marmaris',
#  'Club Sema Suite Hotel',
#  'Chicago hotel',
#  'Club Sultan Maris',
#  'B&B Yüzbaşı Beach',
#  'Ünver Hotel']

# %%
ratings = []
for rating in bsobj.findAll('a',{'class':'ui_bubble_rating'}):
    ratings.append(rating['alt'])
    
ratings
# Out:
# ['5 baloncuk üzerinden\xa05',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa03',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa03,5',
#  '5 baloncuk üzerinden\xa04,5',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa04',
#  '5 baloncuk üzerinden\xa03,5',
#  '5 baloncuk üzerinden\xa02,5']

# %%
reviews = []

for review in bsobj.findAll('a',{'class':'review_count'}):
    reviews.append(review.text.strip())

reviews
# Out:
# ['3.249 yorum',
#  '1.051 yorum',
#  '2.367 yorum',
#  '51 yorum',
#  '28 yorum',
#  '698 yorum',
#  '4.068 yorum',
#  '4.382 yorum',
#  '5.486 yorum',
#  '242 yorum',
#  '551 yorum',
#  '866 yorum',
#  '3.534 yorum',
#  '2.385 yorum',
#  '2.078 yorum',
#  '1.702 yorum',
#  '214 yorum',
#  '698 yorum',
#  '1.172 yorum',
#  '19 yorum',
#  '182 yorum',
#  '417 yorum',
#  '137 yorum',
#  '380 yorum',
#  '130 yorum',
#  '42 yorum',
#  '39 yorum',
#  '304 yorum',
#  '146 yorum',
#  '151 yorum']

# %%
price = []

for p in bsobj.findAll('div',{'class':'price-wrap'}):
    price.append(p.text.replace('₹','').strip())
    
price[:5]
# Out:
# ['₺1.330', '₺295₺279', '₺755', '₺1.277', '₺176₺129']

# %%
len(price)
# Out:
# 30

# %%
d1 = {'Hotel':hotel,'Ratings':ratings,'No_of_Reviews':reviews,'Price':price}

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(d1)
df
# Out:
#                                      Hotel                   Ratings  \
# 0                                Otel Aqua    5 baloncuk üzerinden 5
# 1                           Grand Aquarium  5 baloncuk üzerinden 4,5
# 2                  Golden Rock Beach Hotel  5 baloncuk üzerinden 4,5
# 3                             Pilos Deluxe  5 baloncuk üzerinden 4,5
# 4                        Kemal Butik Hotel    5 baloncuk üzerinden 3
# 5                      TUI BLUE Grand Azur  5 baloncuk üzerinden 4,5
# 6               Green Nature Diamond Hotel  5 baloncuk üzerinden 4,5
# 7                  Blue Bay Platinum Hotel  5 baloncuk üzerinden 4,5
# 8                Green Nature Resort & Spa    5 baloncuk üzerinden 4
# 9                      Motto Premium Hotel  5 baloncuk üzerinden 4,5
# 10                    The Beachfront Hotel  5 baloncuk üzerinden 4,5
# 11                             Club Adakoy  5 baloncuk üzerinden 4,5
# 12                 Labranda Mares Marmaris    5 baloncuk üzerinden 4
# 13       Grand Yazıcı Club Marmaris Palace    5 baloncuk üzerinden 4
# 14                         Paşa Beach Otel  5 baloncuk üzerinden 4,5
# 15               Cettia Beach Resort Hotel  5 baloncuk üzerinden 4,5
# 16                           Sabrinas Haus  5 baloncuk üzerinden 4,5
# 17                    Greenpark Apartments  5 baloncuk üzerinden 4,5
# 18  Elegance Hotels International Marmaris    5 baloncuk üzerinden 4
# 19                   Sunset Hotel Marmaris  5 baloncuk üzerinden 4,5
# 20                              Angels Inn    5 baloncuk üzerinden 4
# 21                  Romance Hotel Marmaris    5 baloncuk üzerinden 4
# 22                          Two Seas Hotel  5 baloncuk üzerinden 4,5
# 23                        Moda Beach Hotel  5 baloncuk üzerinden 3,5
# 24                     City Hotel Marmaris  5 baloncuk üzerinden 4,5
# 25                   Club Sema Suite Hotel    5 baloncuk üzerinden 4
# 26                           Chicago hotel    5 baloncuk üzerinden 4
# 27                       Club Sultan Maris    5 baloncuk üzerinden 4
# 28                       B&B Yüzbaşı Beach  5 baloncuk üzerinden 3,5
# 29                             Ünver Hotel  5 baloncuk üzerinden 2,5
#
#    No_of_Reviews     Price
# 0    3.249 yorum    ₺1.330
# 1    1.051 yorum  ₺295₺279
# 2    2.367 yorum      ₺755
# 3       51 yorum    ₺1.277
# 4       28 yorum  ₺176₺129
# 5      698 yorum
# 6    4.068 yorum
# 7    4.382 yorum
# 8    5.486 yorum
# 9      242 yorum
# 10     551 yorum
# 11     866 yorum
# 12   3.534 yorum
# 13   2.385 yorum
# 14   2.078 yorum
# 15   1.702 yorum
# 16     214 yorum    ₺4.885
# 17     698 yorum
# 18   1.172 yorum
# 19      19 yorum
# 20     182 yorum
# 21     417 yorum
# 22     137 yorum
# 23     380 yorum
# 24     130 yorum
# 25      42 yorum
# 26      39 yorum
# 27     304 yorum
# 28     146 yorum
# 29     151 yorum
